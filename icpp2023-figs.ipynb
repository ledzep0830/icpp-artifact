# %%
# %matplotlib inline
import pandas as pd                
import matplotlib as mpl           
import matplotlib.pyplot as plt

# %%
# train data
slow_horovod_04_01_train = pd.read_csv('/home/hj/paper-data/slow-horovod-04/run-.-tag-train_accuracy.csv')
slow_horovod_04_02_train = pd.read_csv('/home/hj/paper-data/icpp2023/slow-horovod-04-02/run-.-tag-train_accuracy.csv')
slow_horovod_08_01_train = pd.read_csv('/home/hj/paper-data/slow-horovod-08/run-.-tag-train_accuracy.csv')
slow_horovod_08_04_train = pd.read_csv('/home/hj/paper-data/icpp2023/slow-horovod-08-04/run-.-tag-train_accuracy.csv')
slow_horovod_16_01_train = pd.read_csv('/home/hj/paper-data/slow-horovod-16/run-.-tag-train_accuracy.csv')

slow_proposed_04_02_train = pd.read_csv('/home/hj/paper-data/icpp2023/slow-proposed-04-02/run-.-tag-train_accuracy.csv')
slow_proposed_08_01_train = pd.read_csv('/home/hj/paper-data/icpp2023/slow-proposed-08-01/run-.-tag-train_accuracy.csv')
slow_proposed_08_04_train = pd.read_csv('/home/hj/paper-data/icpp2023/slow-proposed-08-04/run-.-tag-train_accuracy.csv')

slow_DPAR_04_02_train = pd.read_csv('/home/hj/paper-data/icpp2023/slow-DPAR-real-04-02/run-.-tag-train_accuracy.csv')

old_noslow_horovod_04_train = pd.read_csv('/home/hj/paper-data/noslow-horovod-04/batch-per-node-128/run-.-tag-train_accuracy.csv')
noslow_horovod_04_train = pd.read_csv('/home/hj/paper-data/icpp2023/noslow-horovod-04/run-.-tag-train_accuracy.csv')
noslow_horovod_08_train = pd.read_csv('/home/hj/paper-data/noslow-horovod-08/batch-per-node-128/run-.-tag-train_accuracy.csv')
noslow_horovod_16_train = pd.read_csv('/home/hj/paper-data/noslow-horovod-16/batch-per-node-128/run-.-tag-train_accuracy.csv')


# val data
slow_horovod_04_01_val = pd.read_csv('/home/hj/paper-data/slow-horovod-04/run-.-tag-val_accuracy.csv')
slow_horovod_04_02_val = pd.read_csv('/home/hj/paper-data/icpp2023/slow-horovod-04-02/run-.-tag-val_accuracy.csv')
slow_horovod_08_01_val = pd.read_csv('/home/hj/paper-data/slow-horovod-08/run-.-tag-val_accuracy.csv')
slow_horovod_08_04_val = pd.read_csv('/home/hj/paper-data/icpp2023/slow-horovod-08-04/run-.-tag-val_accuracy.csv')
slow_horovod_16_01_val = pd.read_csv('/home/hj/paper-data/slow-horovod-16/run-.-tag-val_accuracy.csv')

slow_proposed_04_02_val = pd.read_csv('/home/hj/paper-data/icpp2023/slow-proposed-04-02/run-.-tag-val_accuracy.csv')
slow_proposed_08_01_val = pd.read_csv('/home/hj/paper-data/icpp2023/slow-proposed-08-01/run-.-tag-val_accuracy.csv')
slow_proposed_08_04_val = pd.read_csv('/home/hj/paper-data/icpp2023/slow-proposed-08-04/run-.-tag-val_accuracy.csv')

slow_DPAR_04_02_val = pd.read_csv('/home/hj/paper-data/icpp2023/slow-DPAR-real-04-02/run-.-tag-val_accuracy.csv')

noslow_horovod_04_val = pd.read_csv('/home/hj/paper-data/icpp2023/noslow-horovod-04/run-.-tag-val_accuracy.csv')
noslow_horovod_08_val = pd.read_csv('/home/hj/paper-data/noslow-horovod-08/batch-per-node-128/run-.-tag-val_accuracy.csv')
noslow_horovod_16_val = pd.read_csv('/home/hj/paper-data/noslow-horovod-16/batch-per-node-128/run-.-tag-val_accuracy.csv')

# %%
# train data wall time preprocessing

slow_horovod_04_01_train_new_wall_time = slow_horovod_04_01_train['Wall time'] - slow_horovod_04_01_train['Wall time'][0]
slow_horovod_04_02_train_new_wall_time = slow_horovod_04_02_train['Wall time'] - slow_horovod_04_02_train['Wall time'][0]
slow_horovod_08_01_train_new_wall_time = slow_horovod_08_01_train['Wall time'] - slow_horovod_08_01_train['Wall time'][0]
slow_horovod_08_04_train_new_wall_time = slow_horovod_08_04_train['Wall time'] - slow_horovod_08_04_train['Wall time'][0]
slow_horovod_16_01_train_new_wall_time = slow_horovod_16_01_train['Wall time'] - slow_horovod_16_01_train['Wall time'][0]

slow_proposed_04_02_train_new_wall_time = slow_proposed_04_02_train['Wall time'] - slow_proposed_04_02_train['Wall time'][0]
slow_proposed_08_01_train_new_wall_time = slow_proposed_08_01_train['Wall time'] - slow_proposed_08_01_train['Wall time'][0]
slow_proposed_08_04_train_new_wall_time = slow_proposed_08_04_train['Wall time'] - slow_proposed_08_04_train['Wall time'][0]

slow_DPAR_04_02_train_new_wall_time = slow_DPAR_04_02_train['Wall time'] - slow_DPAR_04_02_train['Wall time'][0]

old_noslow_horovod_04_train_new_wall_time = old_noslow_horovod_04_train['Wall time'] - old_noslow_horovod_04_train['Wall time'][0]
noslow_horovod_04_train_new_wall_time = noslow_horovod_04_train['Wall time'] - noslow_horovod_04_train['Wall time'][0]
noslow_horovod_08_train_new_wall_time = noslow_horovod_08_train['Wall time'] - noslow_horovod_08_train['Wall time'][0]
noslow_horovod_16_train_new_wall_time = noslow_horovod_16_train['Wall time'] - noslow_horovod_16_train['Wall time'][0]

# val data wall time preprocessing

slow_horovod_04_01_val_new_wall_time = slow_horovod_04_01_val['Wall time'] - slow_horovod_04_01_val['Wall time'][0]
slow_horovod_04_02_val_new_wall_time = slow_horovod_04_02_val['Wall time'] - slow_horovod_04_02_val['Wall time'][0]
slow_horovod_08_01_val_new_wall_time = slow_horovod_08_01_val['Wall time'] - slow_horovod_08_01_val['Wall time'][0]
slow_horovod_08_04_val_new_wall_time = slow_horovod_08_04_val['Wall time'] - slow_horovod_08_04_val['Wall time'][0]
slow_horovod_16_01_val_new_wall_time = slow_horovod_16_01_val['Wall time'] - slow_horovod_16_01_val['Wall time'][0]

slow_proposed_04_02_val_new_wall_time = slow_proposed_04_02_val['Wall time'] - slow_proposed_04_02_val['Wall time'][0]
slow_proposed_08_01_val_new_wall_time = slow_proposed_08_01_val['Wall time'] - slow_proposed_08_01_val['Wall time'][0]
slow_proposed_08_04_val_new_wall_time = slow_proposed_08_04_val['Wall time'] - slow_proposed_08_04_val['Wall time'][0]

slow_DPAR_04_02_val_new_wall_time = slow_DPAR_04_02_val['Wall time'] - slow_DPAR_04_02_val['Wall time'][0]

noslow_horovod_04_val_new_wall_time = noslow_horovod_04_val['Wall time'] - noslow_horovod_04_val['Wall time'][0]
noslow_horovod_08_val_new_wall_time = noslow_horovod_08_val['Wall time'] - noslow_horovod_08_val['Wall time'][0]
noslow_horovod_16_val_new_wall_time = noslow_horovod_16_val['Wall time'] - noslow_horovod_16_val['Wall time'][0]

# %%
# train data wall time preprocessing

slow_horovod_04_01_train['New Wall time'] = slow_horovod_04_01_train_new_wall_time
slow_horovod_04_02_train['New Wall time'] = slow_horovod_04_02_train_new_wall_time
slow_horovod_08_01_train['New Wall time'] = slow_horovod_08_01_train_new_wall_time
slow_horovod_08_04_train['New Wall time'] = slow_horovod_08_04_train_new_wall_time
slow_horovod_16_01_train['New Wall time'] = slow_horovod_16_01_train_new_wall_time

slow_proposed_04_02_train['New Wall time'] = slow_proposed_04_02_train_new_wall_time
slow_proposed_08_01_train['New Wall time'] = slow_proposed_08_01_train_new_wall_time
slow_proposed_08_04_train['New Wall time'] = slow_proposed_08_04_train_new_wall_time

slow_DPAR_04_02_train['New Wall time'] = slow_DPAR_04_02_train_new_wall_time

old_noslow_horovod_04_train['New Wall time'] = old_noslow_horovod_04_train_new_wall_time
noslow_horovod_04_train['New Wall time'] = noslow_horovod_04_train_new_wall_time
noslow_horovod_08_train['New Wall time'] = noslow_horovod_08_train_new_wall_time
noslow_horovod_16_train['New Wall time'] = noslow_horovod_16_train_new_wall_time

# val data wall time preprocessing

slow_horovod_04_01_val['New Wall time'] = slow_horovod_04_01_val_new_wall_time
slow_horovod_04_02_val['New Wall time'] = slow_horovod_04_02_val_new_wall_time
slow_horovod_08_01_val['New Wall time'] = slow_horovod_08_01_val_new_wall_time
slow_horovod_08_04_val['New Wall time'] = slow_horovod_08_04_val_new_wall_time
slow_horovod_16_01_val['New Wall time'] = slow_horovod_16_01_val_new_wall_time

slow_proposed_04_02_val['New Wall time'] = slow_proposed_04_02_val_new_wall_time
slow_proposed_08_01_val['New Wall time'] = slow_proposed_08_01_val_new_wall_time
slow_proposed_08_04_val['New Wall time'] = slow_proposed_08_04_val_new_wall_time

slow_DPAR_04_02_val['New Wall time'] = slow_proposed_04_02_val_new_wall_time

noslow_horovod_04_val['New Wall time'] = noslow_horovod_04_val_new_wall_time
noslow_horovod_08_val['New Wall time'] = noslow_horovod_08_val_new_wall_time
noslow_horovod_16_val['New Wall time'] = noslow_horovod_16_val_new_wall_time

# %%
# train data set index

slow_horovod_04_01_train.set_index('New Wall time')
slow_horovod_04_02_train.set_index('New Wall time')
slow_horovod_08_01_train.set_index('New Wall time')
slow_horovod_08_04_train.set_index('New Wall time')
slow_horovod_16_01_train.set_index('New Wall time')

slow_proposed_04_02_train.set_index('New Wall time')
slow_proposed_08_01_train.set_index('New Wall time')
slow_proposed_08_04_train.set_index('New Wall time')

slow_DPAR_04_02_train.set_index('New Wall time')

# val data set index

slow_horovod_04_01_val.set_index('New Wall time')
slow_horovod_04_02_val.set_index('New Wall time')
slow_horovod_08_01_val.set_index('New Wall time')
slow_horovod_08_04_val.set_index('New Wall time')
slow_horovod_16_01_val.set_index('New Wall time')

slow_proposed_04_02_val.set_index('New Wall time')
slow_proposed_08_01_val.set_index('New Wall time')
slow_proposed_08_04_val.set_index('New Wall time')

slow_DPAR_04_02_val.set_index('New Wall time')
# Out:
#                   Wall time  Step     Value
# New Wall time
# 0.000000       1.682081e+09     0  0.482397
# 23.560013      1.682081e+09     1  0.430874
# 46.780107      1.682081e+09     2  0.522844
# 69.339958      1.682081e+09     3  0.580696
# 94.432833      1.682081e+09     4  0.610957
# 117.961253     1.682081e+09     5  0.613825
# 141.879414     1.682081e+09     6  0.660700
# 165.138556     1.682081e+09     7  0.651009
# 187.679315     1.682081e+09     8  0.681863
# 210.568533     1.682081e+09     9  0.711531
# 233.542323     1.682081e+09    10  0.710839
# 256.855856     1.682081e+09    11  0.706092
# 280.477496     1.682081e+09    12  0.726859
# 303.156192     1.682081e+09    13  0.733287
# 327.159039     1.682081e+09    14  0.718453
# 350.462537     1.682081e+09    15  0.754549
# 372.785577     1.682081e+09    16  0.753165
# 395.355845     1.682081e+09    17  0.763944
# 418.129211     1.682081e+09    18  0.751978
# 441.026397     1.682081e+09    19  0.771657
# ...

# %%
# FIGURE 1

plt.figure(dpi=200)

plt.plot(old_noslow_horovod_04_train['New Wall time'], old_noslow_horovod_04_train['Value'], label='AllReduce-04', linestyle='dashdot')
plt.plot(noslow_horovod_08_train['New Wall time'], noslow_horovod_08_train['Value'], label='AllReduce-08', linestyle='dashdot')
plt.plot(noslow_horovod_16_train['New Wall time'], noslow_horovod_16_train['Value'], label='AllReduce-16', linestyle='dashdot')

plt.plot(slow_horovod_04_01_train['New Wall time'], slow_horovod_04_01_train['Value'], label='AllReduce-04-slow')
plt.plot(slow_horovod_08_01_train['New Wall time'], slow_horovod_08_01_train['Value'], label='AllReduce-08-slow')
plt.plot(slow_horovod_16_01_train['New Wall time'], slow_horovod_16_01_train['Value'], label='AllReduce-16-slow')

plt.xlabel('time/s')
plt.ylabel('training accuracy')
plt.grid(True)
plt.legend(loc='lower right')

# %%
# FIGURE 2

plt.figure(dpi=200)

plt.plot(slow_horovod_04_02_train['New Wall time'], slow_horovod_04_02_train['Value'], label='AllReduce-slow', linestyle='dotted')
plt.plot(slow_DPAR_04_02_train['New Wall time'], slow_DPAR_04_02_train['Value'], label='straggler-drop-slow', linestyle='dashdot')
plt.plot(slow_proposed_04_02_train['New Wall time'], slow_proposed_04_02_train['Value'], label='proposed-slow')

plt.xlabel('time/s')
plt.ylabel('training accuracy')
plt.grid(True)
plt.legend(loc='lower right')

# %%
# FIGURE 3

plt.figure(dpi=200)

plt.plot(slow_horovod_04_02_val['New Wall time'], slow_horovod_04_02_val['Value'], label='AllReduce-slow', linestyle='dotted')
plt.plot(slow_DPAR_04_02_val['New Wall time'], slow_DPAR_04_02_val['Value'], label='straggler-drop-slow', linestyle='dashdot')
plt.plot(slow_proposed_04_02_val['New Wall time'], slow_proposed_04_02_val['Value'], label='proposed-slow')

plt.xlabel('time/s')
plt.ylabel('validation accuracy')
plt.grid(True)
plt.legend(loc='lower right')

# %%
# FIGURE 4

plt.figure(dpi=200)

plt.plot(slow_horovod_04_02_train['Step'], slow_horovod_04_02_train['Value'], label='AllReduce-slow', linestyle='dotted')
plt.plot(slow_DPAR_04_02_train['Step'], slow_DPAR_04_02_train['Value'], label='straggler-drop-slow', linestyle='dashdot')
plt.plot(slow_proposed_04_02_train['Step'], slow_proposed_04_02_train['Value'], label='proposed-slow')

plt.xlabel('epoch')
plt.ylabel('training accuracy')
plt.grid(True)
plt.legend(loc='lower right')

# %%
# FIGURE 5

plt.figure(dpi=200)

plt.plot(slow_horovod_04_02_val['Step'], slow_horovod_04_02_val['Value'], label='AllReduce-slow', linestyle='dotted')
plt.plot(slow_DPAR_04_02_val['Step'], slow_DPAR_04_02_val['Value'], label='straggler-drop-slow', linestyle='dashdot')
plt.plot(slow_proposed_04_02_val['Step'], slow_proposed_04_02_val['Value'], label='proposed-slow')

plt.xlabel('epoch')
plt.ylabel('validation accuracy')
plt.grid(True)
plt.legend(loc='lower right')

# %%
# FIGURE 6

import numpy as np

plt.figure(dpi=200)

x = np.arange(3)
experiments = ['AllReduce', 'AllReduce-slow', 'proposed-slow']
values = [1028.948249, 8351.400399, 2050.413439]

plt.bar(x, values, width=0.7)
# plt.bar(x, values, width=0.6)
# plt.bar(x, values, width=0.8)
# plt.bar(x, values, width=1.0)
plt.xticks(x, experiments)
plt.ylabel('time/s')

plt.show()
